# %%
# %run "../utils_loader"

# utils and `session` are now available from the loader
import json
import datetime

# %%
# Use the utils helper which handles pagination
parameters = utils.get_parameters(session, limit=100)
len(parameters)

# %%
from pathlib import Path
out_dir = Path('/Volumes/openaq/bronze_dev/parameters')
out_dir.mkdir(parents=True, exist_ok=True)
with open(out_dir / 'parameters.json', 'w') as f:
    f.write(json.dumps(parameters))
print('wrote', out_dir / 'parameters.json')

# %%
# %sql
select * from read_files('/Volumes/openaq/bronze_dev/parameters/parameters.json')

# %%
#need to make sure I am properly working with pagination. so if limit is les than found go fetch all the pages
