# %%
# %sql
CREATE CATALOG IF NOT EXISTS `openaq`

# %%
# %sql
USE CATALOG openaq;
CREATE SCHEMA IF NOT EXISTS `bronze_dev`;
CREATE SCHEMA IF NOT EXISTS `silver_dev`;
CREATE SCHEMA IF NOT EXISTS `gold_dev`

# %%
# %sql
USE CATALOG openaq;
USE SCHEMA `bronze_dev`;
CREATE VOLUME IF NOT EXISTS locations;
CREATE VOLUME IF NOT EXISTS sensor_data;
CREATE VOLUME IF NOT EXISTS parameters;
